# %%
import hashlib
import logging
import time

logger = logging.getLogger(__name__)
logger.setLevel(logging.WARNING)
logger_sh = logging.StreamHandler()
formatter = logging.Formatter('%(name)s [%(levelname)s] %(message)s')
logger_sh.setFormatter(formatter)
logger.addHandler(logger_sh)

proof.all(False)

try:
    from . import params, ec, hd, misc
    from . import quaternions as qt
    from . import qlapoti as qlpt
except ImportError:
    import params, ec, hd, misc
    import quaternions as qt
    import qlapoti as qlpt

# %%
10401315741927035039.is_prime()
# Out:
# True

# %%
17701784468815527329.bit_length()
# Out:
# 64

# %%
38596101861951626905624152637341212789110997613473673814030974450 - 14615231227706129384
# Out:
# 38596101861951626905624152637341212789110997598858442586324845066

# %%
38596101861951626905624152637341212789110997598858442586324845066 % 1218609823449430187
# Out:
# 0

# %%
Step 5: CVP：直接用 $u_{abs}$ 砸向 $B_{abs\_lll}^{-1}$ 算出 Babai 系数 $c$！

但是这里也要求$B_{abs\_lll}^{-1}$啊，我想知道求$B_{abs\_lll}^{-1}$的逆和前面求B_sublat_lll哪个更快，给你附上我之前的输出，请你参考它们的数值大小，告诉我哪个更好
